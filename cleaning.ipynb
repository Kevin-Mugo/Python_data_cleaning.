# %%
#import libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('fifa21 raw data .csv'  ).set_index('ID')
df.head()
# Out:
# C:\Users\mugok\AppData\Local\Temp\ipykernel_6056\1028078833.py:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('fifa21 raw data .csv'  ).set_index('ID')
#                      Name                      LongName  \
# ID
# 158023           L. Messi                  Lionel Messi
# 20801   Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 200389           J. Oblak                     Jan Oblak
# 192985       K. De Bruyne               Kevin De Bruyne
# 190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                                 photoUrl  \
# ID
# 158023  https://cdn.sofifa.com/players/158/023/21_60.png
# 20801   https://cdn.sofifa.com/players/020/801/21_60.png
# 200389  https://cdn.sofifa.com/players/200/389/21_60.png
# 192985  https://cdn.sofifa.com/players/192/985/21_60.png
# 190871  https://cdn.sofifa.com/players/190/871/21_60.png
#
# ...

# %%
#check the number of rows and columns
df.shape
# Out:
# (18979, 76)

# %%
#Check for column's data types  and null values.
pd.set_option('display.max_rows' , None)
#df.info(verbose=True, show_counts=True)
df.isnull().sum()
# Out:
# Name                    0
# LongName                0
# photoUrl                0
# playerUrl               0
# Nationality             0
# Age                     0
# ↓OVA                    0
# POT                     0
# Club                    0
# Contract                0
# Positions               0
# Height                  0
# Weight                  0
# Preferred Foot          0
# BOV                     0
# Best Position           0
# Joined                  0
# Loan Date End       17966
# Value                   0
# Wage                    0
# Release Clause          0
# Attacking               0
# Crossing                0
# Finishing               0
# Heading Accuracy        0
# Short Passing           0
# Volleys                 0
# Skill                   0
# Dribbling               0
# Curve                   0
# FK Accuracy             0
# Long Passing            0
# Ball Control            0
# Movement                0
# Acceleration            0
# ...

# %% [markdown]
# Data Cleaning.

# %%
#Create a copy of the dataframe.
dfcopy = df.copy()
dfcopy.sample(4)
# Out:
#              Name       LongName  \
# ID
# 148212  A. Rebrov   Artem Rebrov
# 209895   M. Acton  Matthew Acton
# 256892  C. Widell  Casper Widell
# 184176   G. Bruno   Gianni Bruno
#
#                                                 photoUrl  \
# ID
# 148212  https://cdn.sofifa.com/players/148/212/21_60.png
# 209895  https://cdn.sofifa.com/players/209/895/21_60.png
# 256892  https://cdn.sofifa.com/players/256/892/21_60.png
# 184176  https://cdn.sofifa.com/players/184/176/21_60.png
#
#                                                 playerUrl Nationality  Age  \
# ID
# 148212  http://sofifa.com/player/148212/artem-rebrov/2...      Russia   36
# 209895  http://sofifa.com/player/209895/matthew-acton/...   Australia   28
# 256892  http://sofifa.com/player/256892/casper-widell/...      Sweden   17
# 184176  http://sofifa.com/player/184176/gianni-bruno/2...     Belgium   28
#
#         ↓OVA  POT                       Club     Contract   Positions Height  \
# ID
# ...

# %% [markdown]
# CLUB : The current club of a player.

# %%
#Check for datatype
dfcopy['Club'].dtype
# Out:
# dtype('O')

# %%
#check for unique values.
dfcopy['Club'].unique()
# Out:
# array(['\n\n\n\nFC Barcelona', '\n\n\n\nJuventus',
#        '\n\n\n\nAtlético Madrid', '\n\n\n\nManchester City',
#        '\n\n\n\nParis Saint-Germain', '\n\n\n\nFC Bayern München',
#        '\n\n\n\nLiverpool', '\n\n\n\nReal Madrid', '\n\n\n\nChelsea',
#        '\n\n\n\nTottenham Hotspur', '\n\n\n\nInter', '\n\n\n\nNapoli',
#        '\n\n\n\nBorussia Dortmund', '\n\n\n\nManchester United',
#        '\n\n\n\nArsenal', '\n\n\n\nLazio', '\n\n\n\nLeicester City',
#        '\n\n\n\nBorussia Mönchengladbach', '\n\n\n\nReal Sociedad',
#        '\n\n\n\nAtalanta', '\n\n\n\nOlympique Lyonnais', '\n\n\n\nMilan',
#        '\n\n\n\nVillarreal CF', '\n\n\n\nRB Leipzig', '\n\n\n\nCagliari',
#        '\n\n\n\nAjax', '\n\n\n\nSL Benfica', '\n\n\n\nAS Monaco',
#        '\n\n\n\nWolverhampton Wanderers', '\n\n\n\nEverton',
#        '\n\n\n\nFiorentina', '\n\n\n\nFC Porto', '\n\n\n\nRC Celta',
#        '\n\n\n\nTorino', '\n\n\n\nSevilla FC', '\n\n\n\nGrêmio',
# ...

# %%
#Removing the leading spaces.
dfcopy['Club'] = dfcopy['Club'].str.strip()
dfcopy['Club'].unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Atlético Madrid', 'Manchester City',
#        'Paris Saint-Germain', 'FC Bayern München', 'Liverpool',
#        'Real Madrid', 'Chelsea', 'Tottenham Hotspur', 'Inter', 'Napoli',
#        'Borussia Dortmund', 'Manchester United', 'Arsenal', 'Lazio',
#        'Leicester City', 'Borussia Mönchengladbach', 'Real Sociedad',
#        'Atalanta', 'Olympique Lyonnais', 'Milan', 'Villarreal CF',
#        'RB Leipzig', 'Cagliari', 'Ajax', 'SL Benfica', 'AS Monaco',
#        'Wolverhampton Wanderers', 'Everton', 'Fiorentina', 'FC Porto',
#        'RC Celta', 'Torino', 'Sevilla FC', 'Grêmio', 'Real Betis', 'Roma',
#        'Newcastle United', 'Eintracht Frankfurt', 'Valencia CF',
#        'Medipol Başakşehir FK', 'Inter Miami', 'Bayer 04 Leverkusen',
#        'Levante UD', 'Crystal Palace', 'Athletic Club de Bilbao',
#        'Shanghai SIPG FC', 'VfL Wolfsburg',
#        'Guangzhou Evergrande Taobao FC', 'Al Shabab',
# ...

# %% [markdown]
# CONTRACT : Player contract details.

# %%
#check for datatype
dfcopy['Contract'].dtype
# Out:
# dtype('O')

# %%
#check for values in this column.
dfcopy['Contract'].unique()
# Out:
# array(['2004 ~ 2021', '2018 ~ 2022', '2014 ~ 2023', '2015 ~ 2023',
#        '2017 ~ 2022', '2017 ~ 2023', '2018 ~ 2024', '2014 ~ 2022',
#        '2018 ~ 2023', '2016 ~ 2023', '2013 ~ 2023', '2011 ~ 2023',
#        '2009 ~ 2022', '2005 ~ 2021', '2011 ~ 2021', '2015 ~ 2022',
#        '2017 ~ 2024', '2010 ~ 2024', '2012 ~ 2021', '2019 ~ 2024',
#        '2015 ~ 2024', '2017 ~ 2025', '2020 ~ 2025', '2019 ~ 2023',
#        '2008 ~ 2023', '2015 ~ 2021', '2020 ~ 2022', '2012 ~ 2022',
#        '2016 ~ 2025', '2013 ~ 2022', '2011 ~ 2022', '2012 ~ 2024',
#        '2016 ~ 2021', '2012 ~ 2023', '2008 ~ 2022', '2019 ~ 2022',
#        '2017 ~ 2021', '2013 ~ 2024', '2020 ~ 2024', '2010 ~ 2022',
#        '2020 ~ 2021', '2011 ~ 2024', '2020 ~ 2023', '2014 ~ 2024',
#        '2013 ~ 2026', '2016 ~ 2022', '2010 ~ 2021', '2013 ~ 2021',
#        '2019 ~ 2025', '2018 ~ 2025', '2016 ~ 2024', '2018 ~ 2021',
#        '2009 ~ 2024', '2007 ~ 2022', 'Jun 30, 2021 On Loan',
# ...

# %% [markdown]
# From the above we can see we have a mix of date expression formats and also texts.

# %%
for  index , row in dfcopy.iterrows():
    if 'On Loan' in row['Contract'] or 'Free' in row['Contract']:
        print(row['Contract'])
# Out:
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Dec 31, 2020 On Loan
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Jan 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Dec 31, 2020 On Loan
# Jun 30, 2021 On Loan
# ...

# %% [markdown]
# Arrange the column "Contract" into the same format.

# %%
def get_contract(contract):
    if contract == 'Free' or 'On Loan' in contract:
        start_date = np.nan
        end_date = np.nan
        contract_length = 0
    else:
        start_date , end_date = contract.split(' ~ ')
        start_year = int(start_date[:4])
        end_year = int(end_date[:4])
        contract_length = (end_year-start_year)
    return start_date , end_date , contract_length

#Calling the function above to the "Contract column" and creating new columns.

new_columns = ['Contract Start' , 'Contract End' ,'Contract Length (Years)']
new_data = dfcopy['Contract'].apply(lambda x : pd.Series(get_contract(x)))


for i in range(len(new_columns)):
    dfcopy.insert(loc=dfcopy.columns.get_loc('Contract')+1+i , column= new_columns[i] , value = new_data[i])

# %%
pd.set_option('display.max_columns' , None)
dfcopy.head()
# Out:
#                      Name                      LongName  \
# ID
# 158023           L. Messi                  Lionel Messi
# 20801   Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 200389           J. Oblak                     Jan Oblak
# 192985       K. De Bruyne               Kevin De Bruyne
# 190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                                 photoUrl  \
# ID
# 158023  https://cdn.sofifa.com/players/158/023/21_60.png
# 20801   https://cdn.sofifa.com/players/020/801/21_60.png
# 200389  https://cdn.sofifa.com/players/200/389/21_60.png
# 192985  https://cdn.sofifa.com/players/192/985/21_60.png
# 190871  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                                 playerUrl Nationality  Age  \
# ID
# 158023  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 20801   http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
# ...

# %%
dfcopy[['Contract','Contract Start' , 'Contract End' ,'Contract Length (Years)']].sample(50)
# Out:
#                     Contract Contract Start Contract End  \
# ID
# 148729           2014 ~ 2020           2014         2020
# 184471           2019 ~ 2021           2019         2021
# 251900           2019 ~ 2024           2019         2024
# 207421           2019 ~ 2023           2019         2023
# 223473           2019 ~ 2021           2019         2021
# 223968           2019 ~ 2021           2019         2021
# 190883           2019 ~ 2020           2019         2020
# 152480           2006 ~ 2020           2006         2020
# 232031           2020 ~ 2020           2020         2020
# 225678           2018 ~ 2022           2018         2022
# 214893           2020 ~ 2022           2020         2022
# 193283           2018 ~ 2022           2018         2022
# 190015           2019 ~ 2021           2019         2021
# 254131           2019 ~ 2022           2019         2022
# 198190           2018 ~ 2021           2018         2021
# ...

# %%
#Contract categories.

def contract_status(contract):
    if contract == 'Free':
        return "Free"
    elif 'On Loan' in contract:
        return 'On Loan'
    else:
        return "On Contract"

dfcopy.insert(dfcopy.columns.get_loc('Contract Length (Years)')+1 , 'Contract status' , dfcopy['Contract'].apply(contract_status))

dfcopy.sample(5)
# Out:
#                 Name                     LongName  \
# ID
# 230805  A. Boryachuk             Andriy Boryachuk
# 214250   M. Palacios              Manuel Palacios
# 256320     J. DeZart                  Joey DeZart
# 186521   B. Espinosa            Bernardo Espinosa
# 254824  Pedro Mendes  Pedro Manuel Mineiro Mendes
#
#                                                 photoUrl  \
# ID
# 230805  https://cdn.sofifa.com/players/230/805/21_60.png
# 214250  https://cdn.sofifa.com/players/214/250/21_60.png
# 256320  https://cdn.sofifa.com/players/256/320/21_60.png
# 186521  https://cdn.sofifa.com/players/186/521/21_60.png
# 254824  https://cdn.sofifa.com/players/254/824/21_60.png
#
#                                                 playerUrl Nationality  Age  \
# ID
# 230805  http://sofifa.com/player/230805/andriy-boryach...     Ukraine   24
# 214250  http://sofifa.com/player/214250/manuel-palacio...    Colombia   27
# ...

# %%
#Counter check the above operation.
dfcopy[['Contract','Contract Start' , 'Contract End' ,'Contract Length (Years)','Contract status']].sample(50)
# Out:
#                     Contract Contract Start Contract End  \
# ID
# 213619           2020 ~ 2025           2020         2025
# 257213           2020 ~ 2021           2020         2021
# 232243           2019 ~ 2022           2019         2022
# 140293           2018 ~ 2021           2018         2021
# 230432           2019 ~ 2023           2019         2023
# 245277           2017 ~ 2024           2017         2024
# 258365           2020 ~ 2024           2020         2024
# 244348           2018 ~ 2023           2018         2023
# 255233           2018 ~ 2025           2018         2025
# 253527           2012 ~ 2020           2012         2020
# 221797           2018 ~ 2022           2018         2022
# 178253           2018 ~ 2020           2018         2020
# 213155           2020 ~ 2022           2020         2022
# 216478  Jun 30, 2021 On Loan            NaN          NaN
# 202079           2018 ~ 2022           2018         2022
# ...

# %% [markdown]
# HEIGHT : Players height in centimetres.

# %%
#check for height column data type.
dfcopy['Height'].dtype
# Out:
# dtype('O')

# %% [markdown]
# The players heights are object datatype , this is not consistent to the definition. A further step to check why so.

# %%
dfcopy['Height'].unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %%
#convert the "feet\inches" to cm and remove "cm" from centimeters expression to make it integers.
"""def convert_height(height):
    if height[-1] == '"':
        height = height.replace("\"","")
        inch = int(height[2:]) * 2.54
        foot = int(height[0]) * 30.48
        return round(foot+inch)
    elif height[-1] == "m":
        return int(height[:-2])"""

def height_conveter(height):
    if "cm" in height:
        return int(height.strip("cm"))
    else:
        feet, inches = height.split("\'")
        total_inches = int(feet)*12 + int(inches.strip('"'))

        #converting inches  into cm.

        return round(total_inches*2.54)

#apply the function to the height column.
dfcopy['Height'] = dfcopy['Height'].apply(height_conveter)
dfcopy['Height'].unique()
# Out:
# array([170, 187, 188, 181, 175, 184, 191, 178, 193, 185, 199, 173, 168,
#        176, 177, 183, 180, 189, 179, 195, 172, 182, 186, 192, 165, 194,
#        167, 196, 163, 190, 174, 169, 171, 197, 200, 166, 164, 198, 201,
#        158, 162, 161, 160, 203, 157, 156, 202, 159, 206, 155], dtype=int64)

# %%
dfcopy = dfcopy.rename(columns= {'Height':'Height(cm)'})
dfcopy.sample(2)
# Out:
#                   Name                LongName  \
# ID
# 242734      W. Omsberg           Wyatt Omsberg
# 258925  Claudio Mendes  Claudio Mendes Vicente
#
#                                                 photoUrl  \
# ID
# 242734  https://cdn.sofifa.com/players/242/734/21_60.png
# 258925  https://cdn.sofifa.com/players/258/925/21_60.png
#
#                                                 playerUrl    Nationality  Age  \
# ID
# 242734  http://sofifa.com/player/242734/wyatt-omsberg/...  United States   24
# 258925  http://sofifa.com/player/258925/claudio-mendes...          Spain   19
#
#         ↓OVA  POT           Club     Contract Contract Start Contract End  \
# ID
# 242734    61   68   Chicago Fire  2020 ~ 2020           2020         2020
# 258925    63   76  UD Las Palmas  2020 ~ 2021           2020         2021
#
#         Contract Length (Years) Contract status Positions  Height(cm) Weight  \
# ID
# 242734                      0.0     On Contract        CB         193   82kg
# ...

# %% [markdown]
# WEIGHT : Player's weights in kilograms(Kgs).

# %%
dfcopy['Weight'].dtypes
# Out:
# dtype('O')

# %%
#As seen above , the weight column is an object rather than intergers , lets correct that.
#Check for unique values.
dfcopy['Weight'].unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '183lbs', '179lbs', '172lbs', '196lbs', '176lbs', '185lbs',
#        '170lbs', '203lbs', '168lbs', '161lbs', '146lbs', '130lbs',
#        '190lbs', '174lbs', '148lbs', '165lbs', '159lbs', '192lbs',
#        '181lbs', '139lbs', '154lbs', '157lbs', '163lbs', '98kg', '103kg',
#        '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg', '107kg',
#        '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %%
#Convert lbs to kgs and remove "kg" from expressions to make them intergers.
def weight_conversion(weight):
    if "kg" in weight:
        return int(weight.strip("kg"))
    else:
        int_lbs = int(weight.strip('lbs'))

        #converting lbs  into kgs.
        return round(int_lbs/2.205)

#apply the function to the height column.
dfcopy['Weight'] = dfcopy['Weight'].apply(weight_conversion)
dfcopy['Weight'].unique()
# Out:
# array([ 72,  83,  87,  70,  68,  80,  71,  91,  73,  85,  92,  69,  84,
#         96,  81,  82,  75,  86,  89,  74,  76,  64,  78,  90,  66,  60,
#         94,  79,  67,  65,  59,  61,  93,  88,  97,  77,  62,  63,  95,
#        100,  58,  98, 103,  99, 102,  56, 101,  57,  55, 104, 107, 110,
#         53,  50,  54,  52], dtype=int64)

# %%
#Remane the column.
dfcopy = dfcopy.rename(columns = {'Weight': "Weight(Kgs)"})
dfcopy.sample(1)
# Out:
#                   Name                       LongName  \
# ID
# 199674  Jorge Teixeira  Jorge Filipe Avelino Teixeira
#
#                                                 photoUrl  \
# ID
# 199674  https://cdn.sofifa.com/players/199/674/21_60.png
#
#                                                 playerUrl Nationality  Age  \
# ID
# 199674  http://sofifa.com/player/199674/jorge-filipe-a...    Portugal   33
#
#         ↓OVA  POT               Club     Contract Contract Start Contract End  \
# ID
# 199674    69   69  Sint-Truidense VV  2017 ~ 2021           2017         2021
#
#         Contract Length (Years) Contract status Positions  Height(cm)  \
# ID
# 199674                      4.0     On Contract        CB         189
#
#         Weight(Kgs) Preferred Foot  BOV Best Position     Joined  \
# ID
# 199674           89          Right   69            CB  15-Jul-17
#
#        Loan Date End  Value Wage Release Clause  Attacking  Crossing  \
# ID
# ...

# %% [markdown]
# LOAN DATE END : Date when the player's loan ends if on loan.

# %%
#check data type.
dfcopy['Loan Date End'].dtypes
# Out:
# dtype('O')

# %%
#check for unique values.
dfcopy['Loan Date End'].unique()
# Out:
# array([nan, '30-Jun-21', '31-Dec-20', '30-Jan-21', '30-Jun-22',
#        '31-May-21', '05-Jul-21', '31-Dec-21', '01-Jul-21', '01-Jan-21',
#        '31-Aug-21', '31-Jan-21', '30-Dec-21', '23-Jun-21', '03-Jan-21',
#        '27-Nov-21', '17-Jan-21', '30-Jun-23', '31-Jul-21', '22-Nov-20',
#        '31-May-22', '30-Dec-20', '04-Jan-21', '30-Nov-20', '01-Aug-21'],
#       dtype=object)

# %%
dfcopy.sample(5)
# Out:
#                       Name                LongName  \
# ID
# 232838  I. Christie-Davies   Isaac Christie-Davies
# 253715        D. Sarmiento         Darío Sarmiento
# 201447          S. Lletget       Sebastian Lletget
# 256848            H. Koide             Henri Koide
# 190982       Alberto Perea  Alberto Perea Correoso
#
#                                                 photoUrl  \
# ID
# 232838  https://cdn.sofifa.com/players/232/838/21_60.png
# 253715  https://cdn.sofifa.com/players/253/715/21_60.png
# 201447  https://cdn.sofifa.com/players/201/447/21_60.png
# 256848  https://cdn.sofifa.com/players/256/848/21_60.png
# 190982  https://cdn.sofifa.com/players/190/982/21_60.png
#
#                                                 playerUrl    Nationality  Age  \
# ID
# 232838  http://sofifa.com/player/232838/isaac-christie...          Wales   22
# 253715  http://sofifa.com/player/253715/dario-sarmient...      Argentina   17
# ...

# %%
#The dates are ok , lets check for the value of players that are on loan.
on_loan = dfcopy[dfcopy['Contract status'] == 'On Loan']

#View a substring of on_loan.
pd.set_option('display.max_rows', 10)
on_loan[['Contract' , 'Contract status' , 'Loan Date End']]
# Out:
#                     Contract Contract status Loan Date End
# ID
# 173731  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 193105  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 200888  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 216409  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 223959  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# ...                      ...             ...           ...
# 242601  Aug 31, 2021 On Loan         On Loan     31-Aug-21
# 236818  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 240392  Dec 31, 2020 On Loan         On Loan     31-Dec-20
# 252516  Dec 31, 2020 On Loan         On Loan     31-Dec-20
# 232888  Dec 31, 2020 On Loan         On Loan     31-Dec-20
#
# [1013 rows x 3 columns]

# %% [markdown]
# W/F : Player's weak foot rating (Out of 5)

# %%
#check data type
dfcopy['W/F'].dtype
# Out:
# dtype('O')

# %%
#It is an object rather than interger.
dfcopy['W/F'].unique()
# Out:
# array(['4 ★', '3 ★', '5 ★', '2 ★', '1 ★'], dtype=object)

# %%
def convert_weak_foot_rate(rate):
    if "★" in rate:
        return int(rate.strip("★"))
    
#Apply the function to 'W/F' column
dfcopy['W/F'] = dfcopy['W/F'].apply(convert_weak_foot_rate)
dfcopy['W/F'].unique()
# Out:
# array([4, 3, 5, 2, 1], dtype=int64)

# %% [markdown]
# HITS : The number of times the player has been searched in the FIFA database.

# %%
#check data type.

dfcopy['Hits'].dtype
# Out:
# dtype('O')

# %%
#Figure out why
dfcopy['Hits'].unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', '1.6K',
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', '1.1K', '433', '242', '206', '177', '1.5K', '198', '459',
#        '117', '119', '209', '84', '187', '165', '203', '65', '336', '126',
#        '313', '124', '145', '538', '182', '101', '45', '377', '99', '194',
#        '403', '414', '593', '374', '245', '3.2K', '266', '299', '309',
#        '215', '265', '211', '112', '337', '70', '159', '688', '116', '63',
#        '144', '123', '71', '224', '113', '168', '61', '89', '137', '278',
#        '75', '148', '176', '197', '264', '214', '247', '402', '440',
#        '1.7K', '2.3K', '171', '320', '657', '87', '259', '200', '255',
#        '253', '196', '60', '97', '85', '169', '256', '132', '239', '166',
#        '121', '109', '32', '46', '122', '48', '527', '199', '282', '51',
# ...

# %%
def hitchange(h):
    if isinstance(h, str) and "K" in h:
        h = h.replace('K', "")
        h = int(float(h) * 1000)
        return round(h)
    else: 
        return h

#apply the function
dfcopy['Hits'] = dfcopy['Hits'].apply(hitchange)

# Set display options to show numbers without scientific notation
dfcopy['Hits'] = dfcopy['Hits'].astype(str)


dfcopy['Hits'].unique()
# Out:
# array(['nan', '1600.0', '1100.0', '1500.0', '3200.0', '1700.0', '2300.0',
#        '1900.0', '2000.0', '1300.0', '3000.0', '1400.0', '2800.0',
#        '1800.0', '8400.0', '4300.0', '1200.0', '1000.0', '2500.0',
#        '6000.0', '11.0', '2.0', '1.0', '31.0', '3.0', '10.0', '9.0',
#        '17.0', '7.0', '4.0', '6.0'], dtype=object)

# %%
def hitchange(h):
    if isinstance(h, str) and "K" in h:
        h = h.replace('K', "")
        h = int(float(h) * 1000)
        return round(h)
    else:
        return h

# Apply the function to "Hits" column
dfcopy['Hits'] = dfcopy['Hits'].apply(hitchange)

# Convert the column to string to prevent scientific notation
dfcopy['Hits'] = dfcopy['Hits'].astype(str)

# Display unique values in the "Hits" column
unique_hits = dfcopy['Hits'].unique()
print(unique_hits)
# Out:
# ['nan' '1600.0' '1100.0' '1500.0' '3200.0' '1700.0' '2300.0' '1900.0'
#  '2000.0' '1300.0' '3000.0' '1400.0' '2800.0' '1800.0' '8400.0' '4300.0'
#  '1200.0' '1000.0' '2500.0' '6000.0' '11.0' '2.0' '1.0' '31.0' '3.0'
#  '10.0' '9.0' '17.0' '7.0' '4.0' '6.0']
